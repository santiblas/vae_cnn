# %%
# !python ablation_canales.py \
 --serentipia_path serentipia9_ablation.py \
 --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz \
 --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv \
 --roi_order_path /home/diego/Escritorio/limpio/roi_order_131.npy \
 --output_root ./ablation_full_run_fast \
 --classifier logreg \
 --metric auc \
 --outer_folds 3 \
 --epochs_vae 300 \
 --latent_dim 512 \
 --fast \
 --no_early_stop
# Out:
# [INFO] Modo --fast activado. Usando configuración rápida.
#
# ===== ABLAción de canales =====
# Clasificador fijo: logreg
# Canales candidatos: [0:Pearson_OMST_GCE_Signed_Weighted, 1:Pearson_Full_FisherZ_Signed, 2:MI_KNN_Symmetric, 3:dFC_AbsDiffMean, 4:dFC_StdDev, 5:DistanceCorr, 6:Granger_F_lag1]
# Salida raíz: /home/diego/Escritorio/limpio/ablation_full_run_fast
#
# [SINGLE] ch [0:Pearson_OMST_GCE_Signed_Weighted] -> auc=0.5919 ±0.1220
#
# [RUN] /home/diego/anaconda3/envs/serentipia_gpu/bin/python serentipia9_ablation.py --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv --roi_order_path /home/diego/Escritorio/limpio/roi_order_131.npy --output_dir ablation_full_run_fast/single_ch1 --metadata_features Age Sex --classifier_types logreg --gridsearch_scoring roc_auc --outer_folds 3 --repeated_outer_folds_n_repeats 1 --epochs_vae 250 --early_stopping_patience_vae 10 --cyclical_beta_n_cycles 2 --lr_scheduler_type cosine_warm --lr_scheduler_T0 10 --lr_scheduler_eta_min 1e-6 --batch_size 128 --beta_vae 1.2 --dropout_rate_vae 0.2 --latent_dim 128 --n_jobs_gridsearch 1 --optuna_max_trials 10 --optuna_timeout 120 --classifier_use_class_weight --clf_no_tune --no_smote --fast_ablation --channels_to_use 1 --clf_no_tune --no_smote
# ¿GPU visible?: True
# [INFO] [cuML] ➜ no disponible
# torch.cuda.is_available -> True
# torch.version.cuda      -> 12.1
# cupy GPU visible        -> True
# ¿GPU visible?: True
# [INFO] Usando dispositivo: cuda
# [INFO] [FAST PRESET DETECTADO EN serentipia9]
# [INFO] Lista de 131 ROIs guardada en: ablation_full_run_fast/single_ch1/roi_order_131.joblib
# [INFO] Git commit hash: 823b285a218a77026258f78daf4f9a9354ffc060
# [INFO] --- Configuración de la Ejecución (v1.7.0) ---
# [INFO] batch_size: 128
# [INFO] beta_vae: 1.2
# [INFO] channels_to_use: [1]
# [INFO] classifier_calibrate: False
# [INFO] classifier_hp_tune_ratio: 0.25
# [INFO] classifier_stratify_cols: ['Sex']
# [INFO] classifier_types: ['logreg']
# [INFO] classifier_use_class_weight: True
# [INFO] clf_no_tune: True
# [INFO] cyclical_beta_n_cycles: 2
# [INFO] cyclical_beta_ratio_increase: 0.4
# [INFO] decoder_type: convtranspose
# [INFO] dropout_rate_vae: 0.2
# [INFO] early_stopping_patience_vae: 10
# [INFO] epochs_vae: 80
# [INFO] fast_ablation: True
# [INFO] git_hash: 823b285a218a77026258f78daf4f9a9354ffc060
# [INFO] global_tensor_path: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] gridsearch_scoring: roc_auc
# [INFO] inner_folds: 5
# [INFO] intermediate_fc_dim_vae: quarter
# [INFO] latent_dim: 128
# [INFO] latent_features_type: mu
# [INFO] log_interval_epochs_vae: 5
# [INFO] lr_scheduler_T0: 10
# [INFO] lr_scheduler_eta_min: 1e-06
# [INFO] lr_scheduler_patience_vae: 15
# [INFO] lr_scheduler_type: cosine_warm
# [INFO] lr_vae: 0.0001
# [INFO] metadata_features: ['Age', 'Sex']
# [INFO] metadata_path: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv
# [INFO] mlp_classifier_hidden_layers: 64,16
# [INFO] n_jobs_gridsearch: 1
# [INFO] no_smote: True
# [INFO] norm_mode: zscore_offdiag
# [INFO] num_conv_layers_encoder: 4
# [INFO] num_workers: 4
# [INFO] optuna_max_trials: 10
# [INFO] optuna_timeout: 120
# [INFO] outer_folds: 3
# [INFO] output_dir: ablation_full_run_fast/single_ch1
# [INFO] repeated_outer_folds_n_repeats: 1
# [INFO] roi_order_path: /home/diego/Escritorio/limpio/roi_order_131.npy
# [INFO] save_fold_artefacts: False
# [INFO] save_vae_training_history: False
# [INFO] seed: 42
# [INFO] tune_sampler_params: False
# [INFO] use_layernorm_vae_fc: False
# [INFO] use_optuna_pruner: False
# [INFO] use_smote: False
# [INFO] vae_final_activation: linear
# [INFO] vae_val_split_ratio: 0.2
# [INFO] weight_decay_vae: 1e-05
# [INFO] ------------------------------------
# [INFO] Cargando tensor global desde: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] Tensor global cargado. Forma: (431, 7, 131, 131)
# [INFO] Cargando metadatos desde: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv
# [INFO] Metadatos cargados. Forma: (434, 32)
# [INFO] Usando canales seleccionados (índices): [1]
# [INFO] Nombres de canales seleccionados: ['Pearson_Full_FisherZ_Signed']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.048, std=0.777)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E5/80, TrL: 43372.63 (R: 43360.18, KLD: 41.50), Beta: 0.300, LR: 5.57e-05, ValL: 37183.75 (R: 37181.07, KLD: 8.91)
# [INFO]   Fold 1/3 VAE E10/80, TrL: 41333.58 (R: 41304.44, KLD: 43.16), Beta: 0.675, LR: 1.27e-06, ValL: 35582.36 (R: 35570.34, KLD: 17.80)
# [INFO]   Fold 1/3 VAE E15/80, TrL: 37797.38 (R: 37741.73, KLD: 52.99), Beta: 1.050, LR: 5.57e-05, ValL: 30521.10 (R: 30473.30, KLD: 45.53)
# [INFO]   Fold 1/3 VAE E20/80, TrL: 36277.45 (R: 36201.86, KLD: 62.99), Beta: 1.200, LR: 1.27e-06, ValL: 29001.03 (R: 28929.67, KLD: 59.47)
# [INFO]   Fold 1/3 VAE E25/80, TrL: 32368.57 (R: 32231.00, KLD: 114.64), Beta: 1.200, LR: 5.57e-05, ValL: 24286.65 (R: 24009.71, KLD: 230.79)
# [INFO]   Fold 1/3 VAE E30/80, TrL: 30519.57 (R: 30330.55, KLD: 157.52), Beta: 1.200, LR: 1.27e-06, ValL: 23002.92 (R: 22702.77, KLD: 250.12)
# [INFO]   Fold 1/3 VAE E35/80, TrL: 27442.54 (R: 27131.40, KLD: 259.29), Beta: 1.200, LR: 5.57e-05, ValL: 19897.65 (R: 19302.28, KLD: 496.14)
# [INFO]   Fold 1/3 VAE E40/80, TrL: 26165.52 (R: 25818.18, KLD: 289.46), Beta: 1.200, LR: 1.27e-06, ValL: 18994.19 (R: 18452.60, KLD: 451.33)
# [INFO]   Fold 1/3 VAE E45/80, TrL: 24075.11 (R: 23965.92, KLD: 363.95), Beta: 0.300, LR: 5.57e-05, ValL: 16750.18 (R: 16569.96, KLD: 600.73)
# [INFO]   Fold 1/3 VAE E50/80, TrL: 23318.01 (R: 23050.33, KLD: 396.56), Beta: 0.675, LR: 1.27e-06, ValL: 16506.92 (R: 16107.73, KLD: 591.40)
# [INFO]   Fold 1/3 VAE E55/80, TrL: 22193.05 (R: 21809.03, KLD: 365.73), Beta: 1.050, LR: 5.57e-05, ValL: 15558.94 (R: 15042.67, KLD: 491.69)
# [INFO]   Fold 1/3 VAE E60/80, TrL: 21912.81 (R: 21512.38, KLD: 333.69), Beta: 1.200, LR: 1.27e-06, ValL: 15337.85 (R: 14798.55, KLD: 449.42)
# [INFO]   Fold 1/3 VAE E65/80, TrL: 20965.94 (R: 20652.04, KLD: 261.58), Beta: 1.200, LR: 5.57e-05, ValL: 14494.88 (R: 14125.70, KLD: 307.65)
# [INFO]   Fold 1/3 VAE E70/80, TrL: 20508.66 (R: 20223.09, KLD: 237.97), Beta: 1.200, LR: 1.27e-06, ValL: 14317.55 (R: 13966.97, KLD: 292.15)
# [INFO]   Fold 1/3 VAE E75/80, TrL: 19661.58 (R: 19409.18, KLD: 210.34), Beta: 1.200, LR: 5.57e-05, ValL: 13770.92 (R: 13472.69, KLD: 248.52)
# [INFO]   Fold 1/3 VAE E80/80, TrL: 19345.09 (R: 19103.17, KLD: 201.60), Beta: 1.200, LR: 1.27e-06, ValL: 13623.47 (R: 13333.03, KLD: 242.04)
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 13623.4121).
# [INFO]   Fold 1/3 Modelo VAE guardado en: ablation_full_run_fast/single_ch1/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.8000, Bal.Acc=0.6896
# [INFO]   Fold 1/3 completado en 38.53 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.046, std=0.774)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E5/80, TrL: 44205.42 (R: 44192.94, KLD: 41.58), Beta: 0.300, LR: 5.57e-05, ValL: 38419.43 (R: 38416.72, KLD: 9.03)
# [INFO]   Fold 2/3 VAE E10/80, TrL: 42809.48 (R: 42780.24, KLD: 43.32), Beta: 0.675, LR: 1.27e-06, ValL: 36563.48 (R: 36551.37, KLD: 17.94)
# [INFO]   Fold 2/3 VAE E15/80, TrL: 39096.92 (R: 39044.09, KLD: 50.32), Beta: 1.050, LR: 5.57e-05, ValL: 31289.44 (R: 31248.40, KLD: 39.08)
# [INFO]   Fold 2/3 VAE E20/80, TrL: 37381.87 (R: 37314.08, KLD: 56.49), Beta: 1.200, LR: 1.27e-06, ValL: 29887.25 (R: 29827.68, KLD: 49.64)
# [INFO]   Fold 2/3 VAE E25/80, TrL: 33777.19 (R: 33663.39, KLD: 94.84), Beta: 1.200, LR: 5.57e-05, ValL: 24889.16 (R: 24674.57, KLD: 178.83)
# [INFO]   Fold 2/3 VAE E30/80, TrL: 32051.49 (R: 31901.89, KLD: 124.67), Beta: 1.200, LR: 1.27e-06, ValL: 23596.45 (R: 23353.02, KLD: 202.86)
# [INFO]   Fold 2/3 VAE E35/80, TrL: 28563.58 (R: 28293.71, KLD: 224.89), Beta: 1.200, LR: 5.57e-05, ValL: 20158.66 (R: 19556.78, KLD: 501.57)
# [INFO]   Fold 2/3 VAE E40/80, TrL: 27331.08 (R: 27007.13, KLD: 269.95), Beta: 1.200, LR: 1.27e-06, ValL: 19216.81 (R: 18663.54, KLD: 461.06)
# [INFO]   Fold 2/3 VAE E45/80, TrL: 24721.16 (R: 24612.20, KLD: 363.20), Beta: 0.300, LR: 5.57e-05, ValL: 16767.74 (R: 16565.57, KLD: 673.88)
# [INFO]   Fold 2/3 VAE E50/80, TrL: 24045.10 (R: 23773.52, KLD: 402.34), Beta: 0.675, LR: 1.27e-06, ValL: 16467.16 (R: 16026.58, KLD: 652.72)
# [INFO]   Fold 2/3 VAE E55/80, TrL: 22617.05 (R: 22210.09, KLD: 387.58), Beta: 1.050, LR: 5.57e-05, ValL: 15496.56 (R: 14863.16, KLD: 603.23)
# [INFO]   Fold 2/3 VAE E60/80, TrL: 22213.96 (R: 21795.78, KLD: 348.49), Beta: 1.200, LR: 1.27e-06, ValL: 15259.45 (R: 14620.08, KLD: 532.81)
# [INFO]   Fold 2/3 VAE E65/80, TrL: 20854.87 (R: 20530.53, KLD: 270.28), Beta: 1.200, LR: 5.57e-05, ValL: 14406.60 (R: 13980.91, KLD: 354.74)
# [INFO]   Fold 2/3 VAE E70/80, TrL: 20454.26 (R: 20158.45, KLD: 246.51), Beta: 1.200, LR: 1.27e-06, ValL: 14224.12 (R: 13815.55, KLD: 340.47)
# [INFO]   Fold 2/3 VAE E75/80, TrL: 19662.95 (R: 19401.35, KLD: 218.00), Beta: 1.200, LR: 5.57e-05, ValL: 13696.98 (R: 13355.54, KLD: 284.53)
# [INFO]   Fold 2/3 VAE E80/80, TrL: 19248.13 (R: 18997.22, KLD: 209.10), Beta: 1.200, LR: 1.27e-06, ValL: 13581.70 (R: 13241.36, KLD: 283.61)
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 13581.6963).
# [INFO]   Fold 2/3 Modelo VAE guardado en: ablation_full_run_fast/single_ch1/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.7570, Bal.Acc=0.6699
# [INFO]   Fold 2/3 completado en 37.20 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.051, std=0.780)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E5/80, TrL: 45842.45 (R: 45830.02, KLD: 41.44), Beta: 0.300, LR: 5.57e-05, ValL: 38904.00 (R: 38901.37, KLD: 8.75)
# [INFO]   Fold 3/3 VAE E10/80, TrL: 43898.93 (R: 43869.19, KLD: 44.06), Beta: 0.675, LR: 1.27e-06, ValL: 36887.75 (R: 36875.77, KLD: 17.75)
# [INFO]   Fold 3/3 VAE E15/80, TrL: 39596.77 (R: 39541.13, KLD: 52.99), Beta: 1.050, LR: 5.57e-05, ValL: 31486.45 (R: 31440.76, KLD: 43.52)
# [INFO]   Fold 3/3 VAE E20/80, TrL: 38236.68 (R: 38161.91, KLD: 62.30), Beta: 1.200, LR: 1.27e-06, ValL: 29940.33 (R: 29871.97, KLD: 56.96)
# [INFO]   Fold 3/3 VAE E25/80, TrL: 34243.34 (R: 34112.44, KLD: 109.09), Beta: 1.200, LR: 5.57e-05, ValL: 24930.59 (R: 24690.31, KLD: 200.23)
# [INFO]   Fold 3/3 VAE E30/80, TrL: 32496.46 (R: 32317.71, KLD: 148.96), Beta: 1.200, LR: 1.27e-06, ValL: 23571.81 (R: 23295.94, KLD: 229.89)
# [INFO]   Fold 3/3 VAE E35/80, TrL: 28933.94 (R: 28629.23, KLD: 253.92), Beta: 1.200, LR: 5.57e-05, ValL: 20190.97 (R: 19578.98, KLD: 509.99)
# [INFO]   Fold 3/3 VAE E40/80, TrL: 27728.08 (R: 27375.46, KLD: 293.85), Beta: 1.200, LR: 1.27e-06, ValL: 19308.25 (R: 18706.50, KLD: 501.45)
# [INFO]   Fold 3/3 VAE E45/80, TrL: 25308.06 (R: 25191.74, KLD: 387.71), Beta: 0.300, LR: 5.57e-05, ValL: 16838.63 (R: 16616.61, KLD: 740.06)
# [INFO]   Fold 3/3 VAE E50/80, TrL: 24582.06 (R: 24288.44, KLD: 434.98), Beta: 0.675, LR: 1.27e-06, ValL: 16560.09 (R: 16064.57, KLD: 734.10)
# [INFO]   Fold 3/3 VAE E55/80, TrL: 23350.86 (R: 22914.75, KLD: 415.34), Beta: 1.050, LR: 5.57e-05, ValL: 15473.79 (R: 14765.42, KLD: 674.64)
# [INFO]   Fold 3/3 VAE E60/80, TrL: 22712.72 (R: 22236.80, KLD: 396.60), Beta: 1.200, LR: 1.27e-06, ValL: 15192.56 (R: 14455.18, KLD: 614.48)
# [INFO]   Fold 3/3 VAE E65/80, TrL: 21620.71 (R: 21256.38, KLD: 303.61), Beta: 1.200, LR: 5.57e-05, ValL: 14128.16 (R: 13608.67, KLD: 432.91)
# [INFO]   Fold 3/3 VAE E70/80, TrL: 21180.76 (R: 20846.85, KLD: 278.26), Beta: 1.200, LR: 1.27e-06, ValL: 13908.57 (R: 13405.91, KLD: 418.88)
# [INFO]   Fold 3/3 VAE E75/80, TrL: 20327.16 (R: 20034.92, KLD: 243.53), Beta: 1.200, LR: 5.57e-05, ValL: 13251.55 (R: 12808.86, KLD: 368.91)
# [INFO]   Fold 3/3 VAE E80/80, TrL: 20008.50 (R: 19726.55, KLD: 234.96), Beta: 1.200, LR: 1.27e-06, ValL: 13081.72 (R: 12647.53, KLD: 361.82)
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 13081.7197).
# [INFO]   Fold 3/3 Modelo VAE guardado en: ablation_full_run_fast/single_ch1/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.6875, Bal.Acc=0.6385
# [INFO]   Fold 3/3 completado en 38.98 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.7482 +/- 0.0568
# [INFO] Pr_auc              : 0.7765 +/- 0.0508
# [INFO] Accuracy            : 0.6683 +/- 0.0273
# [INFO] Balanced_accuracy   : 0.6660 +/- 0.0258
# [INFO] Sensitivity         : 0.7584 +/- 0.0885
# [INFO] Specificity         : 0.5736 +/- 0.0441
# [INFO] F1_score            : 0.7010 +/- 0.0398
# [INFO] Resultados detallados de todos los clasificadores guardados en: ablation_full_run_fast/single_ch1/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld128_beta1.2_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scoreroc_auc.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: ablation_full_run_fast/single_ch1/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld128_beta1.2_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scoreroc_auc.txt
# [INFO] Pipeline completo en 114.74 segundos.
# [INFO] --- Consideraciones Finales ---
# [INFO] Normalización: 'zscore_offdiag'. Activación VAE: 'linear'. Asegurar compatibilidad.
# [SINGLE] ch [1:Pearson_Full_FisherZ_Signed] -> auc=0.7482 ±0.0568
#
# [RUN] /home/diego/anaconda3/envs/serentipia_gpu/bin/python serentipia9_ablation.py --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv --roi_order_path /home/diego/Escritorio/limpio/roi_order_131.npy --output_dir ablation_full_run_fast/single_ch2 --metadata_features Age Sex --classifier_types logreg --gridsearch_scoring roc_auc --outer_folds 3 --repeated_outer_folds_n_repeats 1 --epochs_vae 250 --early_stopping_patience_vae 10 --cyclical_beta_n_cycles 2 --lr_scheduler_type cosine_warm --lr_scheduler_T0 10 --lr_scheduler_eta_min 1e-6 --batch_size 128 --beta_vae 1.2 --dropout_rate_vae 0.2 --latent_dim 128 --n_jobs_gridsearch 1 --optuna_max_trials 10 --optuna_timeout 120 --classifier_use_class_weight --clf_no_tune --no_smote --fast_ablation --channels_to_use 2 --clf_no_tune --no_smote
# ¿GPU visible?: True
# [INFO] [cuML] ➜ no disponible
# torch.cuda.is_available -> True
# torch.version.cuda      -> 12.1
# cupy GPU visible        -> True
# ¿GPU visible?: True
# [INFO] Usando dispositivo: cuda
# [INFO] [FAST PRESET DETECTADO EN serentipia9]
# [INFO] Lista de 131 ROIs guardada en: ablation_full_run_fast/single_ch2/roi_order_131.joblib
# [INFO] Git commit hash: 823b285a218a77026258f78daf4f9a9354ffc060
# [INFO] --- Configuración de la Ejecución (v1.7.0) ---
# [INFO] batch_size: 128
# [INFO] beta_vae: 1.2
# [INFO] channels_to_use: [2]
# [INFO] classifier_calibrate: False
# [INFO] classifier_hp_tune_ratio: 0.25
# [INFO] classifier_stratify_cols: ['Sex']
# [INFO] classifier_types: ['logreg']
# [INFO] classifier_use_class_weight: True
# [INFO] clf_no_tune: True
# [INFO] cyclical_beta_n_cycles: 2
# [INFO] cyclical_beta_ratio_increase: 0.4
# [INFO] decoder_type: convtranspose
# [INFO] dropout_rate_vae: 0.2
# [INFO] early_stopping_patience_vae: 10
# [INFO] epochs_vae: 80
# [INFO] fast_ablation: True
# [INFO] git_hash: 823b285a218a77026258f78daf4f9a9354ffc060
# [INFO] global_tensor_path: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] gridsearch_scoring: roc_auc
# [INFO] inner_folds: 5
# [INFO] intermediate_fc_dim_vae: quarter
# [INFO] latent_dim: 128
# [INFO] latent_features_type: mu
# [INFO] log_interval_epochs_vae: 5
# [INFO] lr_scheduler_T0: 10
# [INFO] lr_scheduler_eta_min: 1e-06
# [INFO] lr_scheduler_patience_vae: 15
# [INFO] lr_scheduler_type: cosine_warm
# [INFO] lr_vae: 0.0001
# [INFO] metadata_features: ['Age', 'Sex']
# [INFO] metadata_path: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv
# [INFO] mlp_classifier_hidden_layers: 64,16
# [INFO] n_jobs_gridsearch: 1
# [INFO] no_smote: True
# [INFO] norm_mode: zscore_offdiag
# [INFO] num_conv_layers_encoder: 4
# [INFO] num_workers: 4
# [INFO] optuna_max_trials: 10
# [INFO] optuna_timeout: 120
# [INFO] outer_folds: 3
# [INFO] output_dir: ablation_full_run_fast/single_ch2
# [INFO] repeated_outer_folds_n_repeats: 1
# [INFO] roi_order_path: /home/diego/Escritorio/limpio/roi_order_131.npy
# [INFO] save_fold_artefacts: False
# [INFO] save_vae_training_history: False
# [INFO] seed: 42
# [INFO] tune_sampler_params: False
# [INFO] use_layernorm_vae_fc: False
# [INFO] use_optuna_pruner: False
# [INFO] use_smote: False
# [INFO] vae_final_activation: linear
# [INFO] vae_val_split_ratio: 0.2
# [INFO] weight_decay_vae: 1e-05
# [INFO] ------------------------------------
# [INFO] Cargando tensor global desde: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] Tensor global cargado. Forma: (431, 7, 131, 131)
# [INFO] Cargando metadatos desde: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv
# [INFO] Metadatos cargados. Forma: (434, 32)
# [INFO] Usando canales seleccionados (índices): [2]
# [INFO] Nombres de canales seleccionados: ['MI_KNN_Symmetric']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.056, std=0.815)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E5/80, TrL: 43340.70 (R: 43328.28, KLD: 41.43), Beta: 0.300, LR: 5.57e-05, ValL: 37302.20 (R: 37299.48, KLD: 9.07)
# [INFO]   Fold 1/3 VAE E10/80, TrL: 41383.40 (R: 41354.43, KLD: 42.91), Beta: 0.675, LR: 1.27e-06, ValL: 35855.65 (R: 35843.86, KLD: 17.47)
# [INFO]   Fold 1/3 VAE E15/80, TrL: 38085.91 (R: 38034.98, KLD: 48.50), Beta: 1.050, LR: 5.57e-05, ValL: 31269.09 (R: 31234.79, KLD: 32.67)
# [INFO]   Fold 1/3 VAE E20/80, TrL: 36742.72 (R: 36678.99, KLD: 53.10), Beta: 1.200, LR: 1.27e-06, ValL: 30035.64 (R: 29987.66, KLD: 39.98)
# [INFO]   Fold 1/3 VAE E25/80, TrL: 33587.73 (R: 33496.54, KLD: 75.99), Beta: 1.200, LR: 5.57e-05, ValL: 26097.69 (R: 25969.45, KLD: 106.87)
# [INFO]   Fold 1/3 VAE E30/80, TrL: 32039.75 (R: 31921.73, KLD: 98.35), Beta: 1.200, LR: 1.27e-06, ValL: 24963.73 (R: 24802.36, KLD: 134.48)
# [INFO]   Fold 1/3 VAE E35/80, TrL: 29082.50 (R: 28862.99, KLD: 182.92), Beta: 1.200, LR: 5.57e-05, ValL: 21690.17 (R: 21237.20, KLD: 377.48)
# [INFO]   Fold 1/3 VAE E40/80, TrL: 27737.82 (R: 27470.13, KLD: 223.08), Beta: 1.200, LR: 1.27e-06, ValL: 20734.69 (R: 20285.13, KLD: 374.64)
# [INFO]   Fold 1/3 VAE E45/80, TrL: 25502.52 (R: 25406.75, KLD: 319.25), Beta: 0.300, LR: 5.57e-05, ValL: 18286.56 (R: 18101.95, KLD: 615.39)
# [INFO]   Fold 1/3 VAE E50/80, TrL: 24676.53 (R: 24432.95, KLD: 360.86), Beta: 0.675, LR: 1.27e-06, ValL: 17983.62 (R: 17572.41, KLD: 609.19)
# [INFO]   Fold 1/3 VAE E55/80, TrL: 23463.98 (R: 23081.41, KLD: 364.35), Beta: 1.050, LR: 5.57e-05, ValL: 17073.25 (R: 16466.29, KLD: 578.06)
# [INFO]   Fold 1/3 VAE E60/80, TrL: 23166.08 (R: 22762.04, KLD: 336.70), Beta: 1.200, LR: 1.27e-06, ValL: 16855.77 (R: 16219.34, KLD: 530.36)
# [INFO]   Fold 1/3 VAE E65/80, TrL: 22177.60 (R: 21857.04, KLD: 267.14), Beta: 1.200, LR: 5.57e-05, ValL: 16061.75 (R: 15615.94, KLD: 371.51)
# [INFO]   Fold 1/3 VAE E70/80, TrL: 21733.05 (R: 21438.66, KLD: 245.33), Beta: 1.200, LR: 1.27e-06, ValL: 15904.13 (R: 15475.82, KLD: 356.92)
# [INFO]   Fold 1/3 VAE E75/80, TrL: 20964.22 (R: 20708.41, KLD: 213.17), Beta: 1.200, LR: 5.57e-05, ValL: 15368.07 (R: 15023.18, KLD: 287.41)
# [INFO]   Fold 1/3 VAE E80/80, TrL: 20659.09 (R: 20416.18, KLD: 202.43), Beta: 1.200, LR: 1.27e-06, ValL: 15298.60 (R: 14956.02, KLD: 285.49)
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 15269.9277).
# [INFO]   Fold 1/3 Modelo VAE guardado en: ablation_full_run_fast/single_ch2/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.8469, Bal.Acc=0.8042
# [INFO]   Fold 1/3 completado en 35.02 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.060, std=0.812)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E5/80, TrL: 44252.53 (R: 44240.00, KLD: 41.77), Beta: 0.300, LR: 5.57e-05, ValL: 38132.46 (R: 38129.75, KLD: 9.02)
# [INFO]   Fold 2/3 VAE E10/80, TrL: 42845.41 (R: 42816.35, KLD: 43.06), Beta: 0.675, LR: 1.27e-06, ValL: 36367.55 (R: 36355.59, KLD: 17.72)
# [INFO]   Fold 2/3 VAE E15/80, TrL: 39313.18 (R: 39263.71, KLD: 47.11), Beta: 1.050, LR: 5.57e-05, ValL: 31536.48 (R: 31503.99, KLD: 30.95)
# [INFO]   Fold 2/3 VAE E20/80, TrL: 37733.65 (R: 37673.23, KLD: 50.35), Beta: 1.200, LR: 1.27e-06, ValL: 30346.41 (R: 30301.64, KLD: 37.30)
# [INFO]   Fold 2/3 VAE E25/80, TrL: 34699.53 (R: 34618.44, KLD: 67.58), Beta: 1.200, LR: 5.57e-05, ValL: 26342.50 (R: 26231.73, KLD: 92.31)
# [INFO]   Fold 2/3 VAE E30/80, TrL: 33329.38 (R: 33230.63, KLD: 82.29), Beta: 1.200, LR: 1.27e-06, ValL: 25142.19 (R: 25001.16, KLD: 117.53)
# [INFO]   Fold 2/3 VAE E35/80, TrL: 30113.09 (R: 29932.59, KLD: 150.42), Beta: 1.200, LR: 5.57e-05, ValL: 21667.29 (R: 21229.31, KLD: 364.98)
# [INFO]   Fold 2/3 VAE E40/80, TrL: 28785.68 (R: 28554.18, KLD: 192.91), Beta: 1.200, LR: 1.27e-06, ValL: 20755.60 (R: 20299.27, KLD: 380.28)
# [INFO]   Fold 2/3 VAE E45/80, TrL: 26140.30 (R: 26050.63, KLD: 298.90), Beta: 0.300, LR: 5.57e-05, ValL: 18155.71 (R: 17943.73, KLD: 706.60)
# [INFO]   Fold 2/3 VAE E50/80, TrL: 25346.28 (R: 25114.22, KLD: 343.80), Beta: 0.675, LR: 1.27e-06, ValL: 17917.46 (R: 17440.40, KLD: 706.76)
# [INFO]   Fold 2/3 VAE E55/80, TrL: 23958.59 (R: 23576.22, KLD: 364.16), Beta: 1.050, LR: 5.57e-05, ValL: 16957.43 (R: 16192.09, KLD: 728.90)
# [INFO]   Fold 2/3 VAE E60/80, TrL: 23600.93 (R: 23187.64, KLD: 344.40), Beta: 1.200, LR: 1.27e-06, ValL: 16726.04 (R: 15929.49, KLD: 663.79)
# [INFO]   Fold 2/3 VAE E65/80, TrL: 22206.16 (R: 21879.21, KLD: 272.46), Beta: 1.200, LR: 5.57e-05, ValL: 15875.74 (R: 15314.88, KLD: 467.38)
# [INFO]   Fold 2/3 VAE E70/80, TrL: 21813.44 (R: 21504.85, KLD: 257.15), Beta: 1.200, LR: 1.27e-06, ValL: 15724.14 (R: 15188.99, KLD: 445.96)
# [INFO]   Fold 2/3 VAE E75/80, TrL: 20960.18 (R: 20695.51, KLD: 220.56), Beta: 1.200, LR: 5.57e-05, ValL: 15247.48 (R: 14821.54, KLD: 354.95)
# [INFO]   Fold 2/3 VAE E80/80, TrL: 20596.27 (R: 20347.25, KLD: 207.51), Beta: 1.200, LR: 1.27e-06, ValL: 15169.49 (R: 14754.10, KLD: 346.16)
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 15158.1514).
# [INFO]   Fold 2/3 Modelo VAE guardado en: ablation_full_run_fast/single_ch2/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.6419, Bal.Acc=0.5387
# [INFO]   Fold 2/3 completado en 34.07 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.053, std=0.813)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E5/80, TrL: 45902.82 (R: 45890.31, KLD: 41.68), Beta: 0.300, LR: 5.57e-05, ValL: 39783.73 (R: 39781.02, KLD: 9.04)
# [INFO]   Fold 3/3 VAE E10/80, TrL: 44012.24 (R: 43983.13, KLD: 43.13), Beta: 0.675, LR: 1.27e-06, ValL: 37909.16 (R: 37897.35, KLD: 17.49)
# [INFO]   Fold 3/3 VAE E15/80, TrL: 39881.20 (R: 39829.71, KLD: 49.04), Beta: 1.050, LR: 5.57e-05, ValL: 32869.48 (R: 32834.10, KLD: 33.70)
# [INFO]   Fold 3/3 VAE E20/80, TrL: 38617.74 (R: 38552.81, KLD: 54.11), Beta: 1.200, LR: 1.27e-06, ValL: 31520.77 (R: 31470.46, KLD: 41.92)
# [INFO]   Fold 3/3 VAE E25/80, TrL: 35171.61 (R: 35072.34, KLD: 82.73), Beta: 1.200, LR: 5.57e-05, ValL: 27038.10 (R: 26891.76, KLD: 121.95)
# [INFO]   Fold 3/3 VAE E30/80, TrL: 33561.88 (R: 33430.86, KLD: 109.19), Beta: 1.200, LR: 1.27e-06, ValL: 25743.21 (R: 25563.34, KLD: 149.89)
# [INFO]   Fold 3/3 VAE E35/80, TrL: 30117.34 (R: 29874.02, KLD: 202.77), Beta: 1.200, LR: 5.57e-05, ValL: 22077.06 (R: 21597.22, KLD: 399.87)
# [INFO]   Fold 3/3 VAE E40/80, TrL: 28812.37 (R: 28517.68, KLD: 245.58), Beta: 1.200, LR: 1.27e-06, ValL: 21196.69 (R: 20703.03, KLD: 411.38)
# [INFO]   Fold 3/3 VAE E45/80, TrL: 26420.23 (R: 26316.02, KLD: 347.36), Beta: 0.300, LR: 5.57e-05, ValL: 18723.89 (R: 18509.85, KLD: 713.46)
# [INFO]   Fold 3/3 VAE E50/80, TrL: 25606.24 (R: 25335.93, KLD: 400.46), Beta: 0.675, LR: 1.27e-06, ValL: 18403.44 (R: 17925.68, KLD: 707.80)
# [INFO]   Fold 3/3 VAE E55/80, TrL: 24496.15 (R: 24071.20, KLD: 404.71), Beta: 1.050, LR: 5.57e-05, ValL: 17398.71 (R: 16665.87, KLD: 697.95)
# [INFO]   Fold 3/3 VAE E60/80, TrL: 23910.58 (R: 23441.36, KLD: 391.01), Beta: 1.200, LR: 1.27e-06, ValL: 17139.34 (R: 16366.78, KLD: 643.80)
# [INFO]   Fold 3/3 VAE E65/80, TrL: 22855.52 (R: 22487.02, KLD: 307.08), Beta: 1.200, LR: 5.57e-05, ValL: 16140.72 (R: 15591.34, KLD: 457.82)
# [INFO]   Fold 3/3 VAE E70/80, TrL: 22456.33 (R: 22124.02, KLD: 276.92), Beta: 1.200, LR: 1.27e-06, ValL: 15953.85 (R: 15423.11, KLD: 442.28)
# [INFO]   Fold 3/3 VAE E75/80, TrL: 21712.65 (R: 21414.53, KLD: 248.43), Beta: 1.200, LR: 5.57e-05, ValL: 15369.71 (R: 14911.96, KLD: 381.46)
# [INFO]   Fold 3/3 VAE E80/80, TrL: 21436.15 (R: 21157.43, KLD: 232.26), Beta: 1.200, LR: 1.27e-06, ValL: 15242.57 (R: 14796.55, KLD: 371.68)
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 15230.7803).
# [INFO]   Fold 3/3 Modelo VAE guardado en: ablation_full_run_fast/single_ch2/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.5668, Bal.Acc=0.4914
# [INFO]   Fold 3/3 completado en 34.10 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.6852 +/- 0.1450
# [INFO] Pr_auc              : 0.7313 +/- 0.1173
# [INFO] Accuracy            : 0.6131 +/- 0.1693
# [INFO] Balanced_accuracy   : 0.6114 +/- 0.1686
# [INFO] Sensitivity         : 0.6841 +/- 0.1876
# [INFO] Specificity         : 0.5387 +/- 0.1736
# [INFO] F1_score            : 0.6438 +/- 0.1623
# [INFO] Resultados detallados de todos los clasificadores guardados en: ablation_full_run_fast/single_ch2/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld128_beta1.2_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scoreroc_auc.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: ablation_full_run_fast/single_ch2/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld128_beta1.2_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scoreroc_auc.txt
# [INFO] Pipeline completo en 103.22 segundos.
# [INFO] --- Consideraciones Finales ---
# [INFO] Normalización: 'zscore_offdiag'. Activación VAE: 'linear'. Asegurar compatibilidad.
# [SINGLE] ch [2:MI_KNN_Symmetric] -> auc=0.6852 ±0.1450
#
# [RUN] /home/diego/anaconda3/envs/serentipia_gpu/bin/python serentipia9_ablation.py --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv --roi_order_path /home/diego/Escritorio/limpio/roi_order_131.npy --output_dir ablation_full_run_fast/single_ch3 --metadata_features Age Sex --classifier_types logreg --gridsearch_scoring roc_auc --outer_folds 3 --repeated_outer_folds_n_repeats 1 --epochs_vae 250 --early_stopping_patience_vae 10 --cyclical_beta_n_cycles 2 --lr_scheduler_type cosine_warm --lr_scheduler_T0 10 --lr_scheduler_eta_min 1e-6 --batch_size 128 --beta_vae 1.2 --dropout_rate_vae 0.2 --latent_dim 128 --n_jobs_gridsearch 1 --optuna_max_trials 10 --optuna_timeout 120 --classifier_use_class_weight --clf_no_tune --no_smote --fast_ablation --channels_to_use 3 --clf_no_tune --no_smote
# ¿GPU visible?: True
# [INFO] [cuML] ➜ no disponible
# torch.cuda.is_available -> True
# torch.version.cuda      -> 12.1
# cupy GPU visible        -> True
# ¿GPU visible?: True
# [INFO] Usando dispositivo: cuda
# [INFO] [FAST PRESET DETECTADO EN serentipia9]
# [INFO] Lista de 131 ROIs guardada en: ablation_full_run_fast/single_ch3/roi_order_131.joblib
# [INFO] Git commit hash: 823b285a218a77026258f78daf4f9a9354ffc060
# [INFO] --- Configuración de la Ejecución (v1.7.0) ---
# [INFO] batch_size: 128
# [INFO] beta_vae: 1.2
# [INFO] channels_to_use: [3]
# [INFO] classifier_calibrate: False
# [INFO] classifier_hp_tune_ratio: 0.25
# [INFO] classifier_stratify_cols: ['Sex']
# [INFO] classifier_types: ['logreg']
# [INFO] classifier_use_class_weight: True
# [INFO] clf_no_tune: True
# [INFO] cyclical_beta_n_cycles: 2
# [INFO] cyclical_beta_ratio_increase: 0.4
# [INFO] decoder_type: convtranspose
# [INFO] dropout_rate_vae: 0.2
# [INFO] early_stopping_patience_vae: 10
# [INFO] epochs_vae: 80
# [INFO] fast_ablation: True
# [INFO] git_hash: 823b285a218a77026258f78daf4f9a9354ffc060
# [INFO] global_tensor_path: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] gridsearch_scoring: roc_auc
# [INFO] inner_folds: 5
# [INFO] intermediate_fc_dim_vae: quarter
# [INFO] latent_dim: 128
# [INFO] latent_features_type: mu
# [INFO] log_interval_epochs_vae: 5
# [INFO] lr_scheduler_T0: 10
# [INFO] lr_scheduler_eta_min: 1e-06
# [INFO] lr_scheduler_patience_vae: 15
# [INFO] lr_scheduler_type: cosine_warm
# [INFO] lr_vae: 0.0001
# [INFO] metadata_features: ['Age', 'Sex']
# [INFO] metadata_path: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv
# [INFO] mlp_classifier_hidden_layers: 64,16
# [INFO] n_jobs_gridsearch: 1
# [INFO] no_smote: True
# [INFO] norm_mode: zscore_offdiag
# [INFO] num_conv_layers_encoder: 4
# [INFO] num_workers: 4
# [INFO] optuna_max_trials: 10
# [INFO] optuna_timeout: 120
# [INFO] outer_folds: 3
# [INFO] output_dir: ablation_full_run_fast/single_ch3
# [INFO] repeated_outer_folds_n_repeats: 1
# [INFO] roi_order_path: /home/diego/Escritorio/limpio/roi_order_131.npy
# [INFO] save_fold_artefacts: False
# [INFO] save_vae_training_history: False
# [INFO] seed: 42
# [INFO] tune_sampler_params: False
# [INFO] use_layernorm_vae_fc: False
# [INFO] use_optuna_pruner: False
# [INFO] use_smote: False
# [INFO] vae_final_activation: linear
# [INFO] vae_val_split_ratio: 0.2
# [INFO] weight_decay_vae: 1e-05
# [INFO] ------------------------------------
# [INFO] Cargando tensor global desde: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] Tensor global cargado. Forma: (431, 7, 131, 131)
# [INFO] Cargando metadatos desde: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv
# [INFO] Metadatos cargados. Forma: (434, 32)
# [INFO] Usando canales seleccionados (índices): [3]
# [INFO] Nombres de canales seleccionados: ['dFC_AbsDiffMean']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.037, std=0.767)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E5/80, TrL: 42851.70 (R: 42839.23, KLD: 41.58), Beta: 0.300, LR: 5.57e-05, ValL: 37230.99 (R: 37228.04, KLD: 9.84)
# [INFO]   Fold 1/3 VAE E10/80, TrL: 40995.40 (R: 40966.84, KLD: 42.31), Beta: 0.675, LR: 1.27e-06, ValL: 35699.37 (R: 35686.91, KLD: 18.45)
# [INFO]   Fold 1/3 VAE E15/80, TrL: 37919.87 (R: 37874.04, KLD: 43.65), Beta: 1.050, LR: 5.57e-05, ValL: 31599.52 (R: 31573.77, KLD: 24.52)
# [INFO]   Fold 1/3 VAE E20/80, TrL: 36736.33 (R: 36682.66, KLD: 44.73), Beta: 1.200, LR: 1.27e-06, ValL: 30560.18 (R: 30528.64, KLD: 26.28)
# [INFO]   Fold 1/3 VAE E25/80, TrL: 34320.94 (R: 34263.43, KLD: 47.93), Beta: 1.200, LR: 5.57e-05, ValL: 27901.38 (R: 27865.02, KLD: 30.30)
# [INFO]   Fold 1/3 VAE E30/80, TrL: 33299.88 (R: 33240.55, KLD: 49.44), Beta: 1.200, LR: 1.27e-06, ValL: 27181.71 (R: 27143.57, KLD: 31.78)
# [INFO]   Fold 1/3 VAE E35/80, TrL: 31679.97 (R: 31614.32, KLD: 54.71), Beta: 1.200, LR: 5.57e-05, ValL: 25194.66 (R: 25145.89, KLD: 40.64)
# [INFO]   Fold 1/3 VAE E40/80, TrL: 30815.10 (R: 30746.21, KLD: 57.41), Beta: 1.200, LR: 1.27e-06, ValL: 24600.29 (R: 24547.43, KLD: 44.05)
# [INFO]   Fold 1/3 VAE E45/80, TrL: 29224.44 (R: 29203.49, KLD: 69.82), Beta: 0.300, LR: 5.57e-05, ValL: 22671.26 (R: 22649.29, KLD: 73.22)
# [INFO]   Fold 1/3 VAE E50/80, TrL: 28262.42 (R: 28207.24, KLD: 81.75), Beta: 0.675, LR: 1.27e-06, ValL: 22123.03 (R: 22066.23, KLD: 84.13)
# [INFO]   Fold 1/3 VAE E55/80, TrL: 26164.27 (R: 26046.75, KLD: 111.92), Beta: 1.050, LR: 5.57e-05, ValL: 20323.22 (R: 20143.41, KLD: 171.25)
# ...
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.035, std=0.715)
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.310, std=1.091)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.410, std=1.102)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.037, std=0.767)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E5/80, TrL: 146695.80 (R: 146683.40, KLD: 41.37), Beta: 0.300, LR: 5.57e-05, ValL: 143576.25 (R: 143573.27, KLD: 9.97)
# [INFO]   Fold 1/3 VAE E10/80, TrL: 145254.09 (R: 145225.34, KLD: 42.60), Beta: 0.675, LR: 1.27e-06, ValL: 142479.44 (R: 142466.78, KLD: 18.76)
# [INFO]   Fold 1/3 VAE E15/80, TrL: 142469.87 (R: 142421.73, KLD: 45.85), Beta: 1.050, LR: 5.57e-05, ValL: 139143.77 (R: 139114.94, KLD: 27.45)
# [INFO]   Fold 1/3 VAE E20/80, TrL: 141258.68 (R: 141200.88, KLD: 48.16), Beta: 1.200, LR: 1.27e-06, ValL: 138117.73 (R: 138080.78, KLD: 30.79)
# [INFO]   Fold 1/3 VAE E25/80, TrL: 138218.54 (R: 138144.86, KLD: 61.40), Beta: 1.200, LR: 5.57e-05, ValL: 134789.00 (R: 134719.48, KLD: 57.93)
# [INFO]   Fold 1/3 VAE E30/80, TrL: 136709.96 (R: 136622.02, KLD: 73.28), Beta: 1.200, LR: 1.27e-06, ValL: 133756.50 (R: 133669.62, KLD: 72.40)
# [INFO]   Fold 1/3 VAE E35/80, TrL: 133524.08 (R: 133369.90, KLD: 128.48), Beta: 1.200, LR: 5.57e-05, ValL: 129929.95 (R: 129669.77, KLD: 216.81)
# [INFO]   Fold 1/3 VAE E40/80, TrL: 131791.68 (R: 131590.94, KLD: 167.28), Beta: 1.200, LR: 1.27e-06, ValL: 128681.41 (R: 128398.95, KLD: 235.38)
# [INFO]   Fold 1/3 VAE E45/80, TrL: 128134.58 (R: 128048.91, KLD: 285.56), Beta: 0.300, LR: 5.57e-05, ValL: 124830.78 (R: 124673.73, KLD: 523.50)
# [INFO]   Fold 1/3 VAE E50/80, TrL: 126558.60 (R: 126324.16, KLD: 347.32), Beta: 0.675, LR: 1.27e-06, ValL: 123805.70 (R: 123465.55, KLD: 503.92)
# [INFO]   Fold 1/3 VAE E55/80, TrL: 123687.14 (R: 123316.53, KLD: 352.96), Beta: 1.050, LR: 5.57e-05, ValL: 120689.10 (R: 120182.66, KLD: 482.32)
# [INFO]   Fold 1/3 VAE E60/80, TrL: 122561.33 (R: 122159.87, KLD: 334.55), Beta: 1.200, LR: 1.27e-06, ValL: 119758.91 (R: 119239.98, KLD: 432.44)
# [INFO]   Fold 1/3 VAE E65/80, TrL: 120032.77 (R: 119696.96, KLD: 279.84), Beta: 1.200, LR: 5.57e-05, ValL: 116823.05 (R: 116448.52, KLD: 312.11)
# [INFO]   Fold 1/3 VAE E70/80, TrL: 118929.65 (R: 118614.67, KLD: 262.48), Beta: 1.200, LR: 1.27e-06, ValL: 116119.93 (R: 115741.70, KLD: 315.19)
# [INFO]   Fold 1/3 VAE E75/80, TrL: 116597.82 (R: 116289.50, KLD: 256.94), Beta: 1.200, LR: 5.57e-05, ValL: 113734.12 (R: 113379.79, KLD: 295.28)
# [INFO]   Fold 1/3 VAE E80/80, TrL: 115581.63 (R: 115284.01, KLD: 248.02), Beta: 1.200, LR: 1.27e-06, ValL: 113077.92 (R: 112729.90, KLD: 290.02)
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 113077.9219).
# [INFO]   Fold 1/3 Modelo VAE guardado en: ablation_full_run_fast/step6_add_ch3_set_1_5_2_4_0_6_3/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.6531, Bal.Acc=0.6594
# [INFO]   Fold 1/3 completado en 48.63 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 7 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.046, std=0.774)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.401, std=1.689)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.060, std=0.812)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.034, std=0.714)
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.309, std=1.090)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.099)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.035, std=0.766)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E5/80, TrL: 146933.75 (R: 146921.34, KLD: 41.37), Beta: 0.300, LR: 5.57e-05, ValL: 142617.89 (R: 142615.03, KLD: 9.55)
# [INFO]   Fold 2/3 VAE E10/80, TrL: 145770.05 (R: 145741.71, KLD: 41.97), Beta: 0.675, LR: 1.27e-06, ValL: 141462.78 (R: 141450.72, KLD: 17.88)
# [INFO]   Fold 2/3 VAE E15/80, TrL: 142868.50 (R: 142820.85, KLD: 45.38), Beta: 1.050, LR: 5.57e-05, ValL: 138105.83 (R: 138079.03, KLD: 25.53)
# [INFO]   Fold 2/3 VAE E20/80, TrL: 141541.26 (R: 141484.46, KLD: 47.33), Beta: 1.200, LR: 1.27e-06, ValL: 137174.97 (R: 137140.77, KLD: 28.50)
# [INFO]   Fold 2/3 VAE E25/80, TrL: 138646.00 (R: 138578.24, KLD: 56.46), Beta: 1.200, LR: 5.57e-05, ValL: 133853.55 (R: 133798.58, KLD: 45.81)
# [INFO]   Fold 2/3 VAE E30/80, TrL: 137364.04 (R: 137285.11, KLD: 65.77), Beta: 1.200, LR: 1.27e-06, ValL: 132824.17 (R: 132757.78, KLD: 55.32)
# [INFO]   Fold 2/3 VAE E35/80, TrL: 134094.58 (R: 133967.74, KLD: 105.70), Beta: 1.200, LR: 5.57e-05, ValL: 128749.82 (R: 128553.23, KLD: 163.82)
# [INFO]   Fold 2/3 VAE E40/80, TrL: 132530.85 (R: 132367.55, KLD: 136.09), Beta: 1.200, LR: 1.27e-06, ValL: 127470.30 (R: 127245.75, KLD: 187.12)
# [INFO]   Fold 2/3 VAE E45/80, TrL: 128594.30 (R: 128521.29, KLD: 243.35), Beta: 0.300, LR: 5.57e-05, ValL: 123182.21 (R: 123044.81, KLD: 458.00)
# [INFO]   Fold 2/3 VAE E50/80, TrL: 127094.70 (R: 126894.18, KLD: 297.06), Beta: 0.675, LR: 1.27e-06, ValL: 122049.34 (R: 121749.09, KLD: 444.80)
# [INFO]   Fold 2/3 VAE E55/80, TrL: 123933.95 (R: 123578.15, KLD: 338.86), Beta: 1.050, LR: 5.57e-05, ValL: 118539.21 (R: 118049.12, KLD: 466.75)
# [INFO]   Fold 2/3 VAE E60/80, TrL: 122625.53 (R: 122233.05, KLD: 327.07), Beta: 1.200, LR: 1.27e-06, ValL: 117472.85 (R: 116971.27, KLD: 417.98)
# [INFO]   Fold 2/3 VAE E65/80, TrL: 119781.39 (R: 119439.81, KLD: 284.66), Beta: 1.200, LR: 5.57e-05, ValL: 114134.51 (R: 113753.16, KLD: 317.78)
# [INFO]   Fold 2/3 VAE E70/80, TrL: 118496.35 (R: 118162.67, KLD: 278.07), Beta: 1.200, LR: 1.27e-06, ValL: 113254.08 (R: 112882.83, KLD: 309.38)
# [INFO]   Fold 2/3 VAE E75/80, TrL: 115989.98 (R: 115669.37, KLD: 267.18), Beta: 1.200, LR: 5.57e-05, ValL: 110496.49 (R: 110153.45, KLD: 285.87)
# [INFO]   Fold 2/3 VAE E80/80, TrL: 115006.22 (R: 114698.34, KLD: 256.56), Beta: 1.200, LR: 1.27e-06, ValL: 109728.64 (R: 109388.75, KLD: 283.24)
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 109711.1797).
# [INFO]   Fold 2/3 Modelo VAE guardado en: ablation_full_run_fast/step6_add_ch3_set_1_5_2_4_0_6_3/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.6710, Bal.Acc=0.6382
# [INFO]   Fold 2/3 completado en 50.75 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 7 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.051, std=0.780)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.425, std=1.798)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.053, std=0.813)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.036, std=0.714)
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.309, std=1.092)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.101)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.036, std=0.767)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=10)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E5/80, TrL: 146488.75 (R: 146476.32, KLD: 41.45), Beta: 0.300, LR: 5.57e-05, ValL: 133650.39 (R: 133647.48, KLD: 9.67)
# [INFO]   Fold 3/3 VAE E10/80, TrL: 145267.97 (R: 145239.20, KLD: 42.63), Beta: 0.675, LR: 1.27e-06, ValL: 132550.30 (R: 132537.94, KLD: 18.31)
# [INFO]   Fold 3/3 VAE E15/80, TrL: 142067.49 (R: 142019.44, KLD: 45.76), Beta: 1.050, LR: 5.57e-05, ValL: 129206.85 (R: 129178.83, KLD: 26.69)
# [INFO]   Fold 3/3 VAE E20/80, TrL: 140979.09 (R: 140921.04, KLD: 48.37), Beta: 1.200, LR: 1.27e-06, ValL: 128276.95 (R: 128240.81, KLD: 30.11)
# [INFO]   Fold 3/3 VAE E25/80, TrL: 138158.91 (R: 138086.12, KLD: 60.66), Beta: 1.200, LR: 5.57e-05, ValL: 125104.37 (R: 125039.29, KLD: 54.23)
# [INFO]   Fold 3/3 VAE E30/80, TrL: 136671.37 (R: 136582.29, KLD: 74.24), Beta: 1.200, LR: 1.27e-06, ValL: 124016.11 (R: 123935.27, KLD: 67.37)
# [INFO]   Fold 3/3 VAE E35/80, TrL: 133172.17 (R: 133017.92, KLD: 128.54), Beta: 1.200, LR: 5.57e-05, ValL: 120106.39 (R: 119872.75, KLD: 194.70)
# [INFO]   Fold 3/3 VAE E40/80, TrL: 131582.54 (R: 131386.94, KLD: 163.00), Beta: 1.200, LR: 1.27e-06, ValL: 118857.68 (R: 118590.55, KLD: 222.61)
# [INFO]   Fold 3/3 VAE E45/80, TrL: 127902.54 (R: 127820.24, KLD: 274.33), Beta: 0.300, LR: 5.57e-05, ValL: 115008.12 (R: 114860.64, KLD: 491.63)
# [INFO]   Fold 3/3 VAE E50/80, TrL: 126507.29 (R: 126285.24, KLD: 328.96), Beta: 0.675, LR: 1.27e-06, ValL: 114057.33 (R: 113707.49, KLD: 518.27)
# [INFO]   Fold 3/3 VAE E55/80, TrL: 123710.18 (R: 123337.29, KLD: 355.14), Beta: 1.050, LR: 5.57e-05, ValL: 111068.02 (R: 110534.14, KLD: 508.46)
# [INFO]   Fold 3/3 VAE E60/80, TrL: 122318.05 (R: 121917.93, KLD: 333.43), Beta: 1.200, LR: 1.27e-06, ValL: 110180.70 (R: 109612.70, KLD: 473.34)
# [INFO]   Fold 3/3 VAE E65/80, TrL: 119758.42 (R: 119428.28, KLD: 275.12), Beta: 1.200, LR: 5.57e-05, ValL: 107154.48 (R: 106747.45, KLD: 339.19)
# [INFO]   Fold 3/3 VAE E70/80, TrL: 118573.36 (R: 118252.78, KLD: 267.15), Beta: 1.200, LR: 1.27e-06, ValL: 106365.92 (R: 105956.27, KLD: 341.37)
# [INFO]   Fold 3/3 VAE E75/80, TrL: 116363.32 (R: 116051.14, KLD: 260.14), Beta: 1.200, LR: 5.57e-05, ValL: 103915.16 (R: 103516.16, KLD: 332.51)
# [INFO]   Fold 3/3 VAE E80/80, TrL: 115302.59 (R: 115000.10, KLD: 252.08), Beta: 1.200, LR: 1.27e-06, ValL: 103265.09 (R: 102886.55, KLD: 315.44)
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 103239.5391).
# [INFO]   Fold 3/3 Modelo VAE guardado en: ablation_full_run_fast/step6_add_ch3_set_1_5_2_4_0_6_3/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 130)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO]       (sin tuning) logreg entrenado con hiperparámetros por defecto.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.7759, Bal.Acc=0.7667
# [INFO]   Fold 3/3 completado en 51.54 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.7000 +/- 0.0663
# [INFO] Pr_auc              : 0.6753 +/- 0.0834
# [INFO] Accuracy            : 0.6904 +/- 0.0702
# [INFO] Balanced_accuracy   : 0.6881 +/- 0.0689
# [INFO] Sensitivity         : 0.7574 +/- 0.0749
# [INFO] Specificity         : 0.6188 +/- 0.0636
# [INFO] F1_score            : 0.7158 +/- 0.0686
# [INFO] Resultados detallados de todos los clasificadores guardados en: ablation_full_run_fast/step6_add_ch3_set_1_5_2_4_0_6_3/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld128_beta1.2_normzscore_offdiag_ch7sel_intFCquarter_drop0.2_ln0_outer3x1_scoreroc_auc.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: ablation_full_run_fast/step6_add_ch3_set_1_5_2_4_0_6_3/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld128_beta1.2_normzscore_offdiag_ch7sel_intFCquarter_drop0.2_ln0_outer3x1_scoreroc_auc.txt
# [INFO] Pipeline completo en 151.00 segundos.
# [INFO] --- Consideraciones Finales ---
# [INFO] Normalización: 'zscore_offdiag'. Activación VAE: 'linear'. Asegurar compatibilidad.
#   + probar [3:dFC_AbsDiffMean] -> auc=0.7000
# [CHOICE] agrego canal [3:dFC_AbsDiffMean] → auc=0.7000 (Δ=-0.0402)
#
# [OK] Resumen guardado en: /home/diego/Escritorio/limpio/ablation_full_run_fast/summary_ablation.csv
# Contenido (corto):
#    step  ... delta_vs_prev
# 0     0  ...           NaN
# 1     1  ...      0.011075
# 2     2  ...     -0.010772
# 3     3  ...     -0.005376
# 4     4  ...     -0.026576
# 5     5  ...      0.023633
# 6     6  ...     -0.040163
#
# [7 rows x 6 columns]
